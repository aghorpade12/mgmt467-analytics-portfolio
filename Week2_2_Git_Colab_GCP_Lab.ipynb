# %% [markdown]
# # Week 2.2 Lab: GitHub + Colab + GCP Integration

# %% [markdown]
# In this guided lab, you will practice setting up your **team workflow** by connecting GitHub, Google Colab, Google Drive,
# and Google Cloud Platform (GCP). By the end, you will have a working notebook saved in your team repo and authenticated to GCP.
#
# **Learning Objectives:**
# - Create and configure a GitHub account (if not already done).
# - Create or join your **team repository** on GitHub.
# - Connect Colab to Google Drive for data and notebook persistence.
# - Authenticate Colab to access GCP services (BigQuery, Storage).
# - Save your Colab notebook to your GitHub repository.

# %% [markdown]
# ## 1. GitHub Account & Team Repository

# %% [markdown]
# 1. Go to [https://github.com](https://github.com) and create an account (if you don’t already have one).
# 2. One teammate should create a new repository (e.g., `MGMT467_TeamX`), set it to **Private**, and add collaborators.
# 3. Each team member should **accept the invite** to the repo.
# 4. Confirm by cloning the repo locally or simply viewing it online.
#
# :bulb: Later labs will rely on this shared repo for collaboration.

# %% [markdown]
# ## 2. Connect Colab to Google Drive

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Check contents (optional)
# !ls /content/drive/MyDrive
# Out:
# Mounted at /content/drive
# '1.4.1_Project- Semester 2 Honors Chemistry - Aditya Ghorpade.docx'
# '1.4.1 Project - Semester 2 Honors Chemistry Project, Part 1_Aditya_Ghorpade.docx'
# '1.5.1 Practice.docx'
# '1.5.4 Test(TST)_Aditya_Ghorpade.docx'
# '2019 Stanford Individual Waiver.gdoc'
# '2019 Stanford Individual Waiver.pdf'
# '2020-08-26 13-12 1.pdf'
# '2020-08-26 13-12.pdf'
# '2020-08-31 10-28.pdf'
# '2020-08-31 16-11.pdf'
# '2020-09-01 13-50.pdf'
# '2020-09-01 14-33.pdf'
# '2020-09-03 11-30.pdf'
# '2020-09-04 09-17.pdf'
# '2020-09-04 10-02.pdf'
# '2020-09-08 14-30.pdf'
# '2020-09-08 14-49.pdf'
# '2020-09-11 09-52.pdf'
# '2020-09-11 11-33 (1).pdf'
# '2020-09-11 11-33.pdf'
# '2020-09-15 13-35.pdf'
# '2020-09-15 14-55 (1).pdf'
# '2020-09-15 14-55.pdf'
# '2020-09-17 11-19.pdf'
# '2020-09-18 09-37 (1).pdf'
# '2020-09-18 09-37 (2).pdf'
# '2020-09-18 09-37.pdf'
# '2020-09-21 09-34 (1).pdf'
# '2020-09-21 09-34 (2).pdf'
# '2020-09-21 09-34.pdf'
# '2020-09-22 14-23.pdf'
# '2020-09-24 11-45.pdf'
# '2020-09-25 09-59 (1).pdf'
# '2020-09-25 09-59.pdf'
# '2020-09-28 10-12.pdf'
# '2020-09-29 13-51.pdf'
# '2020-09-29 14-47.pdf'
# '2020-10-01 11-55(d).pdf'
# '2020-10-01 11-55.pdf'
# '2020-10-02 09-00.pdf'
# '2020-10-05 11-38.pdf'
# '2020-10-08 09-13.pdf'
# '2020-10-08 11-51.pdf'
# '2020-10-12 09-55.pdf'
# '2020-10-16 09-41.pdf'
# '2020-10-16 09-47.pdf'
# '2020-10-20 14-15.pdf'
# '2020-10-27 14-44.pdf'
# '2020-11-05 13-18.pdf'
# '2020-11-10 14-48.pdf'
# '2020-11-14 10-03.pdf'
# '2020-11-14 10-05.pdf'
# '2020-11-14 10-06.pdf'
# '2020-11-17 14-37 (1).pdf'
# '2020-11-17 14-37.pdf'
# '2020-11-19 12-47 (1).pdf'
# '2020-11-19 12-47.pdf'
# '2021-01-12 09-25.pdf'
# '2.4.1 Project Semester 2 Honors Chemistry - Aditya Ghorpade.docx'
# '2.5.3 Test (TST) - Eat, Drink, and Be Ordered Around (Test).docx'
# '2.5.4_Test(TST) - Aditya Ghorpade.docx'
# '2-capacitors (1).pdf'
# '2-Potential (1).pdf'
# '2-Resistivity Lab (1).pdf'
# '3.1.5 Explore Passive Solar Homes (done).docx'
# '3.2.5 Explore Calories and Calorimetry.docx'
#  3.3.5.gdoc
# '3.5.1 Practice Transfering Engery.docx'
# '3.5.4 Test(TST)_Aditya_Ghorpade.docx'
# '4.1.5_Explore_Particle-Wave Duality of Light - Aditya Ghorpade.docx'
# '4.3.5 Explore_Nuclear_Medicine.docx'
# '4.4.1 Final Project Paper - Aditya Ghorpade.docx'
# '4.5.4 Test(TST) - Aditya Ghorpade.docx'
# '5.1.5 Explore Protein Structure and Function - Aditya Ghorpade.docx'
# '5.3.5 Explore Using Alternative Energies - Aditya Ghorpade.docx'
# '5.5.4 Test(TST) - Aditya Ghorpade.docx'
# '6.1.3 Final Exam Chemistry Semester 2 - Aditya Ghorpade.docx'
# '6-chhaya-Chemistry nuclear activities 1-4 (1).gdoc'
# '6-chhaya-Chemistry nuclear activities 1-4 (1).pdf'
#  6-Singh-IsotopeLab.gdoc
#  6-Singh-IsotopeLab.pdf
# 'Act III, Scene 4 Short Discussion Questions.docx'
# 'Act III, Scene 4 Short Discussion Questions.gdoc'
# 'Adi G - Evolution quiz answer sheet.gdoc'
# 'Adi G - Evolution Quiz-Bio with apps 2020.pdf'
# 'Adi G - Lizard-Evolution-Virtual-Lab-Student-Worksheet.pdf'
# 'Aditya - Essentials of Innovation v3 (1).docx'
# 'Aditya - Essentials of Innovation v3 (2).docx'
# 'Aditya - Essentials of Innovation v3.docx'
#  Aditya_Extracuricular__College_List.xlsx
# 'Aditya G - Extracurricular Diary v1 (FINAL).gsheet'
# 'Aditya Ghorpade - Common App Activities vFinal.docx'
#  aditya_ghorpade_extraJava.gdoc
#  Aditya_Ghorpade_Resume.docx
#  Aditya_Ghorpade_Resume.pdf
# 'Aditya Ghorpade - ____ State Prompt Matching vFinal.docx'
# 'Aditya Ghorpade - UC Prompt Matching vFinal.docx'
# 'Aditya Resume (1).pdf'
# 'Aditya Resume (2).pdf'
# 'Aditya Resume One.pdf'
# 'Aditya Resume.pdf'
# 'App Launch Package files-20220521T195956Z-001.zip'
# 'Bill To Remove Confederate Buildings.gdoc'
# 'Biodiversity Quiz Answers - Aditya Ghorpade.gdoc'
# 'Bragsheet - Aditya Ghorpade.gdoc'
#  Brain_Bee_MasterMind_Team
# 'BUSI 22-DDA-SUM21.doc'
# 'BYU Geo'
#  CCIR
# 'chem 4.4.4 graph.gdoc'
#  Civil_War_Paper.docx.gdoc
#  Civil_War_Paper.docx.pdf
#  Classroom
# 'Colab Notebooks'
#  College
# 'College Apps'
# 'Common App Activities v1 Aditya Ghorpade.docx'
#  Convergence.jpg
# 'Copy of Aditya Ghorpade - Scores and Stats.xlsx'
# 'Copy of Aditya Resume.docx'
# 'Copy of AP Physics C: E&M - Auto Dates.gsheet'
# 'Copy of Battle of Vimy Ridge Thesis Infographics by Slidesgo (1).gslides'
# 'Copy of Battle of Vimy Ridge Thesis Infographics by Slidesgo (2).gslides'
# 'Copy of Battle of Vimy Ridge Thesis Infographics by Slidesgo (3).gslides'
# 'Copy of Battle of Vimy Ridge Thesis Infographics by Slidesgo.gslides'
# 'Copy of Doppler Effect Lab Copy.gdoc'
# 'Coronavirus Journal Entries.gdoc'
# 'Cover Letter - Aditya Ghorpade(microsoft).docx'
# 'DECA competitions overview.JPG'
# 'Econ Chapter 2 Notes.gdoc'
# 'Essay Launch Questions.docx'
# 'Essay Personal Questions.docx'
# 'Explore 1.2.5 Explore Food Colloids (done).docx'
# 'Explore 1.3.5 Mining Helium (done).docx'
# 'Explore 2.25 Explore Acid Rain Ecosystems (done).docx'
# 'Explore 3.3.5 - Aditya Ghorpade.docx'
# 'Extracurricular Diary - Template (CAN OPEN IN GOOGLE SHEETS).xlsx'
# 'Final Country Project_Part5.pptx'
# 'Flower Garden Lab.gdoc'
# '<.gdoc'
# 'Ghorpade, Aditya - Essay Writing.pptx'
#  HeartRateLab.pdf
#  History_043_Journal_Entries.pdf
# 'History Journal - Aditya.gdoc'
# 'History Journal Entries.gdoc'
#  HS
# 'IB Essay Application - Aditya Ghorpade.gdoc'
#  image1.jpeg
#  IMG_1983.JPG
#  IMG_1984.JPG
#  IMG_1985.JPG
#  IMG_1986.JPG
#  IMG_1987.JPG
#  IMG_1992.JPG
#  IMG_1993.JPG
#  IMG_1994.JPG
#  IMG_1995.JPG
#  IMG_1997.JPG
#  IMG_1999.JPG
#  IMG_2244.jpg
#  IMG_2298.JPG
#  IMG_3098.MOV
#  IMG_7519.MOV
#  IMG_9435.jpg
# 'Important stuff'
# 'In-Depth Focus [Updated 2022] - Group 2.gdoc'
#  Introduction_Video.mp4
#  Istart_res.docx
# 'Kami Schoology Assignments'
# 'Kami Uploads'
#  Labs.gdoc
# 'Lawerence Hall.gdoc'
#  Lesson_7_Cold_War_Timeline.pdf
# 'Lesson Notes Presentation.gslides'
# 'List of Colleges.xlsx'
# 'List Of Universities.gsheet'
# 'Macbeth Act III Summative Assessment Short Discussion Questions.docx'
# 'Macbeth Act III Summative Assessment Short Discussion Questions.gdoc'
# 'Macbeth Act III Vocabulary Test.docx'
# 'Macbeth Act II Test.docx'
# 'Macbeth Act II Test.gdoc'
# 'Macbeth, Odysseus, and Oedipus at a cafe in the Afterlife..docx'
# 'Macbeth, Odysseus, and Oedipus at a cafe in the Afterlife..gdoc'
# 'Macbeth Semester 2 Final Test - Aditya Ghorpade.gdoc'
# 'Macbeth Semester 2 Final Test.docx'
# 'Medication Schedular.gdoc'
# 'msg-rvgx-dcr - May 11, 2023.pdf'
# 'My ESO 2015'
# 'My stuff'
# 'Natural Selection Lab.pdf'
#  Notes.gdoc
#  nvidia.docx
#  PechaKuchaPresentation.mp4
#  Personal
# 'Pharmaceutical Price Controls: PuFo Debate(NEG).gdoc'
#  Photo.pdf
# 'Physics Final Exam.gdoc'
# 'Physics Final Exam(work).pdf'
# 'Physics HW #10.pdf'
# 'Physics HW #11.pdf'
# 'Physics HW #12.pdf'
# 'Physics HW #14.pdf'
# 'Physics HW #15.pdf'
# 'Physics HW #16 (1).pdf'
# 'Physics HW #16.pdf'
# 'Physics HW #18.pdf'
# 'Physics HW #19.pdf'
# 'Physics HW #20.pdf'
# 'Physics HW #21.pdf'
# 'Physics HW #22.pdf'
# 'Physics HW #2.pdf'
# 'Physics HW #3.pdf'
# 'Physics HW #4.pdf'
# 'Physics HW #5.pdf'
# 'Physics HW #6.pdf'
# 'Physics HW #7.pdf'
# 'Physics HW #8.pdf'
# 'Physics HW #9.pdf'
# 'Physics HW.pdf'
# 'Physics Quiz #10.pdf'
# 'Physics Quiz #11.pdf'
# 'Physics Quiz #12.pdf'
# 'Physics Quiz #13.pdf'
# 'Physics Quiz #14.pdf'
# 'Physics Quiz #15.pdf'
# 'Physics Quiz #16.pdf'
# 'Physics Quiz #17.pdf'
# 'Physics Quiz #18.pdf'
# 'Physics Quiz #19.pdf'
# 'Physics Quiz #1.pdf'
# 'Physics Quiz #20.pdf'
# 'Physics Quiz #21.pdf'
# 'Physics Quiz #22.pdf'
# 'Physics Quiz #23.pdf'
# 'Physics Quiz #2.pdf'
# 'Physics Quiz #3.pdf'
# 'Physics Quiz #4.pdf'
# 'Physics Quiz #5.pdf'
# 'Physics Quiz #6.pdf'
# 'Physics Quiz #7.pdf'
# 'Physics Quiz #8.pdf'
# 'Physics Quiz #9.pdf'
# 'Physics Unit 1 Exam.pdf'
# 'Physics Unit 2 Exam.pdf'
# 'Physics Unit 2 Test Corrections.pdf'
# 'Physics Unit 3 Exam.pdf'
# 'Physics Unit 3 Test Corrections.pdf'
# 'Physics Unit 4 Exam.pdf'
# 'Physics Unit 4 Test Corrections.pdf'
# 'Physics Unit 5 Exam.pdf'
#  plant1.jpg
#  plant2.jpg
#  plant3.jpg
#  plant4.jpg
#  practice.gdoc
#  Project_1.docx
#  Project_Part2.docx
#  Project_Part3.docx
#  Project_Part_4.docx
# 'Quiz Ch.8.gdoc'
# 'Realidades 2 Syllabus 2021JP (1).gdoc'
# 'Realidades 2 Syllabus 2021JP (2).gdoc'
# 'Realidades 2 Syllabus 2021JP.docx'
# 'Realidades 2 Syllabus 2021JP.gdoc'
# 'Rec letter (math).gdoc'
#  Rec_Math.docx
# 'Research Edward the Confessor and why is he included in Macbeth.docx'
# 'Research Edward the Confessor and why is he included in Macbeth.gdoc'
# 'Resume - Aditya Ghorpade.docx'
# 'ReTree Volunteer Form.gform'
#  Rice_pic.jpeg
# 'Rice Pics.gdoc'
# 'Saved from Chrome'
#  Science_Alliance
# 'Screenshot 2025-02-03 at 4.20.57 PM.jpeg'
#  Screenshots
# 'Semester_2_Final.pdf (1).gdoc'
# 'Semester_2_Final.pdf (1).pdf'
# 'Slave Voyages.pdf'
# 'social media script.gdoc'
# 'Sophomore Enrichment Classroom Links.docx'
#  speeches.gdoc
#  Standord_OnlineEssay.docx
#  Standord_OnlineEssay.gdoc
# 'Stanford Speeches.gdoc'
# 'Students in Ukraine by Aditya Ghorpade.gslides'
# 'Summer 2020'
# 'Summer 2022'
# 'Summer 2023'
#  Teacher_appreciation..docx
# 'Test 1 Delta SAQ.gdoc'
# 'Test 1 Delta SAQ.pdf'
# 'The Conqueror from a Dying Kingdom_01 [JNC][Premium].pdf'
# 'The Conqueror from a Dying Kingdom_02 [JNC][Premium].pdf'
# 'The Conqueror from a Dying Kingdom_03 [JNC][Premium].pdf'
# 'The Conqueror from a Dying Kingdom_04 [JNC][Premium].pdf'
# 'The Conqueror from a Dying Kingdom_05 [JNC][Premium].pdf'
# 'The Conqueror from a Dying Kingdom_06 [JNC][Premium].pdf'
# 'The Conqueror from a Dying Kingdom_07 [JNC].pdf'
# 'The Macbeths and Gender Roles.docx'
# 'The Macbeths and Gender Roles.gdoc'
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled presentation.gslides'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'US History'
# 'US History 20-21 Syllabus.gdoc'
# 'US History 20-21 Syllabus.pdf'
#  UW_common_app_vFinal.gdoc
#  UW_common_app_vFinal.pdf
# 'Workout Routine.gdoc'
# 'Young Scientist Challenge.gdoc'

# %% [markdown]
# ## 3. Authenticate GCP in Colab

# %%
from google.colab import auth
auth.authenticate_user()

print("Authenticated to GCP successfully!")
# Out:
# Authenticated to GCP successfully!

# %% [markdown]
# Once authenticated, you can access BigQuery and other GCP services from this notebook.

# %% [markdown]
# ## 4. Run a BigQuery Sanity Query

# %%
from google.cloud import bigquery

# Create a BigQuery client
client = bigquery.Client(project="sunlit-plasma-471119-s7")

# Simple test query: public dataset
query = "SELECT name, SUM(number) as total FROM `bigquery-public-data.usa_names.usa_1910_2013` GROUP BY name ORDER BY total DESC LIMIT 5"
results = client.query(query).to_dataframe()

display(results)
# Out:
#       name    total
# 0    James  4942431
# 1     John  4834422
# 2   Robert  4718787
# 3  Michael  4297230
# 4  William  3822209

# %% [markdown]
# ## 5. Save Notebook to GitHub

# %% [markdown]
# To push from Colab to GitHub, you can use a **personal access token (PAT)**.
#
# **Steps:**
# 1. On GitHub, go to **Settings → Developer settings → Personal access tokens (classic)**.
# 2. Generate a token with `repo` permissions (set expiry to ~7 days for safety).
# 3. In Colab, use the snippet below to push your notebook back to GitHub.
#
# :warning: Do **NOT** hardcode tokens in notebooks. Use `getpass` to input securely.

# %%
import os
from getpass import getpass

# Enter your GitHub credentials
username = "aghorpade12"
token = getpass("Enter your GitHub token: ")
repo = "mgmt467-analytics-portfolio"  # e.g., MGMT467_TeamX
notebook_filename = "/content/drive/MyDrive/College/Year 3/Semester 1/MGMT 467/Practice/Week2_2_Git_Colab_GCP_Lab.ipynb"

# Save notebook to GitHub
# !git config --global user.name "{username}"
# !git config --global user.email "{username}@users.noreply.github.com"
# !git clone https://{username}:{token}@github.com/{username}/{repo}.git

# Copy notebook into repo
# !cp "{notebook_filename}" {repo}/

# Commit and push
# !cd {repo} && git add . && git commit -m "Added Week 2.2 Lab notebook" && git push
# Out:
# Enter your GitHub token: ··········
# fatal: destination path 'mgmt467-analytics-portfolio' already exists and is not an empty directory.
# cp: cannot stat '/content/drive/MyDrive/College/Year': No such file or directory
# cp: cannot stat '3/Semester': No such file or directory
# cp: cannot stat '1/MGMT': No such file or directory
# cp: cannot stat '467/Practice/Week2_2_Git_Colab_GCP_Lab.ipynb': No such file or directory
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %% [markdown]
# ## ✅ Exit Ticket

# %% [markdown]
# Before you leave, make sure you have:
# - [ ] Mounted Google Drive in Colab
# - [ ] Authenticated to GCP successfully
# - [ ] Run the BigQuery sanity check
# - [ ] Saved your notebook to your team GitHub repo
#
# Upload your GitHub repo link to Brightspace as proof of completion.
